# %% [markdown]
# <a href="https://colab.research.google.com/github/harsh-busam04/assignment_ml/blob/main/Untitled10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
import pandas as pd

# Upload a file manually
uploaded = files.upload()

# Read the uploaded Excel file (replace 'your_file.xlsx' with the actual filename)
df = pd.read_excel('/content/Toyota.xlsx')

# Display the first few rows
df.head()
# Out:
#      <input type="file" id="files-0569a376-ed78-4ad4-9e92-bb1d4ac11bc6" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-0569a376-ed78-4ad4-9e92-bb1d4ac11bc6">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
from google.colab import files
import pandas as pd
from sklearn.preprocessing import StandardScaler


uploaded = files.upload()


df = pd.read_excel('/content/Toyota.xlsx')


print("Original DataFrame:")
print(df.head())


scaler = StandardScaler()


numeric_cols = df.select_dtypes(include=['number']).columns


df[numeric_cols] = scaler.fit_transform(df[numeric_cols])


print("\nScaled DataFrame:")
print(df.head())
# Out:
#      <input type="file" id="files-6d4ff198-3a68-41d1-b9eb-ef7903cedc40" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-6d4ff198-3a68-41d1-b9eb-ef7903cedc40">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
from google.colab import files
import pandas as pd

# Upload a file manually
uploaded = files.upload()

# Read the uploaded Excel file
df = pd.read_excel('/content/Toyota.xlsx')

# Select only numeric columns before computing correlation
df_numeric = df.select_dtypes(include=['number'])

# Compute the correlation matrix
correlation_matrix = df_numeric.corr()

# Display the correlation matrix
print("Correlation Matrix:")
print(correlation_matrix)
# Out:
#      <input type="file" id="files-75fecffd-59ee-48b0-8a5c-0d79470ac326" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-75fecffd-59ee-48b0-8a5c-0d79470ac326">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
from google.colab import files
import pandas as pd
import statsmodels.api as sm
import statsmodels.formula.api as smf

# Upload a file manually
uploaded = files.upload()

# Read the uploaded Excel file
df = pd.read_excel('/content/Toyota.xlsx')

# Display the first few rows
print("First 5 rows of the dataset:")
print(df.head())

# Ensure required columns exist
required_columns = ["Price", "Age", "Mileage"]
missing_columns = [col for col in required_columns if col not in df.columns]

if missing_columns:
    print(f"Error: The following columns are missing from the dataset: {missing_columns}")
else:
    # Perform linear regression
    model = smf.ols("Price ~ Age + Mileage", data=df).fit()

    # Print regression summary
    print("\nRegression Summary:")
    print(model.summary())
# Out:
#      <input type="file" id="files-22660286-033c-4170-8af8-e68525c8a21a" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-22660286-033c-4170-8af8-e68525c8a21a">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...
